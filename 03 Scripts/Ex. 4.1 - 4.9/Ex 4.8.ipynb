# %% [markdown]
# # 01. Importing Libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import Data

# %%
# path shortcut
path = r'C:\Users\georg\Documents\2025-02-05 Instacart Basket Analysis'

# %%
# import prepared orders & products dataset
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_revised.pkl'))

# %% [markdown]
# # 03. Grouping & Aggregating Data

# %% [markdown]
# ## 03.01 Single Aggregation

# %%
# finding the average number of orders by dept - using single aggregation
df_ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# #### When we compare the full dataset to the subset, we can see some differences. The means are a bit different but still pretty close. For example, in the full dataset, the means for departments 1, 2, and 3 are 15.45, 17.28, and 17.17. But in the subset, those same departments have means of 14.8, 17.09, and 17.91

# %% [markdown]
# ## 03.02 Loyalty Flag

# %%
# creating a new column to count the max number of orders placed by each user. 
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\georg\AppData\Local\Temp\ipykernel_20144\3271832234.py:2: FutureWarning: The provided callable <function max at 0x00000217B47D0400> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              0             0   2539329        1             1
# 2              0             0   2539329        1             1
# 3              0             0   2539329        1             1
# 4              0             0   2539329        1             1
# 5              1             1   2398795        1             2
# 6              1             1   2398795        1             2
# 7              1             1   2398795        1             2
# 8              1             1   2398795        1             2
# 9              1             1   2398795        1             2
# 10             1             1   2398795        1             2
# 11             2             2    473747        1             3
# 12             2             2    473747        1             3
# 13             2             2    473747        1             3
# 14             2             2    473747        1             3
#
#     order_day_of_week  time_of_order  days_since_prior_order  product_id  \
# 0                   2              8                     NaN         196
# 1                   2              8                     NaN       14084
# 2                   2              8                     NaN       12427
# 3                   2              8                     NaN       26088
# 4                   2              8                     NaN       26405
# 5                   3              7                    15.0         196
# 6                   3              7                    15.0       10258
# 7                   3              7                    15.0       12427
# 8                   3              7                    15.0       13176
# 9                   3              7                    15.0       26088
# 10                  3              7                    15.0       13032
# 11                  3             12                    21.0         196
# 12                  3             12                    21.0       12427
# 13                  3             12                    21.0       10258
# 14                  3             12                    21.0       25133
#
#     add_to_cart_order  ...                             product_name  aisle_id  \
# 0                   1  ...                                     Soda        77
# 1                   2  ...  Organic Unsweetened Vanilla Almond Milk        91
# 2                   3  ...                      Original Beef Jerky        23
# 3                   4  ...               Aged White Cheddar Popcorn        23
# 4                   5  ...         XL Pick-A-Size Paper Towel Rolls        54
# 5                   1  ...                                     Soda        77
# 6                   2  ...                               Pistachios       117
# 7                   3  ...                      Original Beef Jerky        23
# 8                   4  ...                   Bag of Organic Bananas        24
# 9                   5  ...               Aged White Cheddar Popcorn        23
# 10                  6  ...                    Cinnamon Toast Crunch       121
# 11                  1  ...                                     Soda        77
# 12                  2  ...                      Original Beef Jerky        23
# 13                  3  ...                               Pistachios       117
# 14                  4  ...                    Organic String Cheese        21
#
#    department_id  prices  _merge    price_range_loc     busiest_day  \
# 0              7     9.0    both  Mid range product  Regularly busy
# 1             16    12.5    both  Mid range product  Regularly busy
# 2             19     4.4    both  Low range product  Regularly busy
# 3             19     4.7    both  Low range product  Regularly busy
# 4             17     1.0    both  Low range product  Regularly busy
# 5              7     9.0    both  Mid range product  Regularly busy
# 6             19     3.0    both  Low range product  Regularly busy
# 7             19     4.4    both  Low range product  Regularly busy
# 8              4    10.3    both  Mid range product  Regularly busy
# 9             19     4.7    both  Low range product  Regularly busy
# 10            14     4.0    both  Low range product  Regularly busy
# 11             7     9.0    both  Mid range product  Regularly busy
# 12            19     4.4    both  Low range product  Regularly busy
# 13            19     3.0    both  Low range product  Regularly busy
# 14            16     8.6    both  Mid range product  Regularly busy
#
#     day_activity_level busiest_period_of_day max_order
# 0       Regularly busy        Average Orders        10
# 1       Regularly busy        Average Orders        10
# 2       Regularly busy        Average Orders        10
# 3       Regularly busy        Average Orders        10
# 4       Regularly busy        Average Orders        10
# 5   Least busiest days        Average Orders        10
# 6   Least busiest days        Average Orders        10
# 7   Least busiest days        Average Orders        10
# 8   Least busiest days        Average Orders        10
# 9   Least busiest days        Average Orders        10
# 10  Least busiest days        Average Orders        10
# 11  Least busiest days           Most Orders        10
# 12  Least busiest days           Most Orders        10
# 13  Least busiest days           Most Orders        10
# 14  Least busiest days           Most Orders        10
#
# [15 rows x 22 columns]

# %%
# Assigning Loyalty Flag
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
df_summary = df_ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['sum', 'mean', 'min', 'max']})

# %%
df_summary
# Out:
#                        prices
#                           sum       mean  min      max
# loyalty_flag
# Loyal customer    106814042.2  10.386336  1.0  99999.0
# New customer       83011787.2  13.294670  1.0  99999.0
# Regular customer  198391693.2  12.495717  1.0  99999.0

# %% [markdown]
# #### Not too sure about the min & max prices.
# #### We can tell that in total, the regular customers spent the most - almost double what teh loyal customers spent (198M vs 106M) - while new customers spent the least at 83M
# #### New customers on the other hand that the largest average amount spent per order, coming out to 13.3 . Loyal customers averaged the least with 10.4 and Regular customers spent 12.5 on average

# %% [markdown]
# ## 03.03 Spending Flag

# %%
# creating a new column to calculate the average amount spent by each user id. 
df_ords_prods_merge['avg_product_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\georg\AppData\Local\Temp\ipykernel_20144\3846347510.py:2: FutureWarning: The provided callable <function mean at 0x00000217B47D0E00> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_ords_prods_merge['avg_product_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              0             0   2539329        1             1
# 2              0             0   2539329        1             1
# 3              0             0   2539329        1             1
# 4              0             0   2539329        1             1
# 5              1             1   2398795        1             2
# 6              1             1   2398795        1             2
# 7              1             1   2398795        1             2
# 8              1             1   2398795        1             2
# 9              1             1   2398795        1             2
# 10             1             1   2398795        1             2
# 11             2             2    473747        1             3
# 12             2             2    473747        1             3
# 13             2             2    473747        1             3
# 14             2             2    473747        1             3
#
#     order_day_of_week  time_of_order  days_since_prior_order  product_id  \
# 0                   2              8                     NaN         196
# 1                   2              8                     NaN       14084
# 2                   2              8                     NaN       12427
# 3                   2              8                     NaN       26088
# 4                   2              8                     NaN       26405
# 5                   3              7                    15.0         196
# 6                   3              7                    15.0       10258
# 7                   3              7                    15.0       12427
# 8                   3              7                    15.0       13176
# 9                   3              7                    15.0       26088
# 10                  3              7                    15.0       13032
# 11                  3             12                    21.0         196
# 12                  3             12                    21.0       12427
# 13                  3             12                    21.0       10258
# 14                  3             12                    21.0       25133
#
#     add_to_cart_order  ...  department_id  prices _merge    price_range_loc  \
# 0                   1  ...              7     9.0   both  Mid range product
# 1                   2  ...             16    12.5   both  Mid range product
# 2                   3  ...             19     4.4   both  Low range product
# 3                   4  ...             19     4.7   both  Low range product
# 4                   5  ...             17     1.0   both  Low range product
# 5                   1  ...              7     9.0   both  Mid range product
# 6                   2  ...             19     3.0   both  Low range product
# 7                   3  ...             19     4.4   both  Low range product
# 8                   4  ...              4    10.3   both  Mid range product
# 9                   5  ...             19     4.7   both  Low range product
# 10                  6  ...             14     4.0   both  Low range product
# 11                  1  ...              7     9.0   both  Mid range product
# 12                  2  ...             19     4.4   both  Low range product
# 13                  3  ...             19     3.0   both  Low range product
# 14                  4  ...             16     8.6   both  Mid range product
#
#        busiest_day  day_activity_level busiest_period_of_day max_order  \
# 0   Regularly busy      Regularly busy        Average Orders        10
# 1   Regularly busy      Regularly busy        Average Orders        10
# 2   Regularly busy      Regularly busy        Average Orders        10
# 3   Regularly busy      Regularly busy        Average Orders        10
# 4   Regularly busy      Regularly busy        Average Orders        10
# 5   Regularly busy  Least busiest days        Average Orders        10
# 6   Regularly busy  Least busiest days        Average Orders        10
# 7   Regularly busy  Least busiest days        Average Orders        10
# 8   Regularly busy  Least busiest days        Average Orders        10
# 9   Regularly busy  Least busiest days        Average Orders        10
# 10  Regularly busy  Least busiest days        Average Orders        10
# 11  Regularly busy  Least busiest days           Most Orders        10
# 12  Regularly busy  Least busiest days           Most Orders        10
# 13  Regularly busy  Least busiest days           Most Orders        10
# 14  Regularly busy  Least busiest days           Most Orders        10
#
#     loyalty_flag avg_product_price
# 0   New customer          6.367797
# 1   New customer          6.367797
# 2   New customer          6.367797
# 3   New customer          6.367797
# 4   New customer          6.367797
# 5   New customer          6.367797
# 6   New customer          6.367797
# 7   New customer          6.367797
# 8   New customer          6.367797
# 9   New customer          6.367797
# 10  New customer          6.367797
# 11  New customer          6.367797
# 12  New customer          6.367797
# 13  New customer          6.367797
# 14  New customer          6.367797
#
# [15 rows x 24 columns]

# %%
# Assigning spending flag
df_ords_prods_merge.loc[df_ords_prods_merge['avg_product_price'] < 10, 'spending_flag'] = 'Low Spender'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['avg_product_price'] >= 10, 'spending_flag'] = 'High Spender'

# %%
df_ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low Spender     31770614
# High Spender      634245
# Name: count, dtype: int64

# %% [markdown]
# ## 03.04 Order Frequency Flag

# %%
# creating a new column to calculate the average amount spent by each user id. 
df_ords_prods_merge['medain_days_since_last_order'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\georg\AppData\Local\Temp\ipykernel_20144\237626874.py:2: FutureWarning: The provided callable <function median at 0x00000217B492BA60> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df_ords_prods_merge['medain_days_since_last_order'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df_ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              0             0   2539329        1             1
# 2              0             0   2539329        1             1
# 3              0             0   2539329        1             1
# 4              0             0   2539329        1             1
# 5              1             1   2398795        1             2
# 6              1             1   2398795        1             2
# 7              1             1   2398795        1             2
# 8              1             1   2398795        1             2
# 9              1             1   2398795        1             2
# 10             1             1   2398795        1             2
# 11             2             2    473747        1             3
# 12             2             2    473747        1             3
# 13             2             2    473747        1             3
# 14             2             2    473747        1             3
#
#     order_day_of_week  time_of_order  days_since_prior_order  product_id  \
# 0                   2              8                     NaN         196
# 1                   2              8                     NaN       14084
# 2                   2              8                     NaN       12427
# 3                   2              8                     NaN       26088
# 4                   2              8                     NaN       26405
# 5                   3              7                    15.0         196
# 6                   3              7                    15.0       10258
# 7                   3              7                    15.0       12427
# 8                   3              7                    15.0       13176
# 9                   3              7                    15.0       26088
# 10                  3              7                    15.0       13032
# 11                  3             12                    21.0         196
# 12                  3             12                    21.0       12427
# 13                  3             12                    21.0       10258
# 14                  3             12                    21.0       25133
#
#     add_to_cart_order  ...  _merge    price_range_loc     busiest_day  \
# 0                   1  ...    both  Mid range product  Regularly busy
# 1                   2  ...    both  Mid range product  Regularly busy
# 2                   3  ...    both  Low range product  Regularly busy
# 3                   4  ...    both  Low range product  Regularly busy
# 4                   5  ...    both  Low range product  Regularly busy
# 5                   1  ...    both  Mid range product  Regularly busy
# 6                   2  ...    both  Low range product  Regularly busy
# 7                   3  ...    both  Low range product  Regularly busy
# 8                   4  ...    both  Mid range product  Regularly busy
# 9                   5  ...    both  Low range product  Regularly busy
# 10                  6  ...    both  Low range product  Regularly busy
# 11                  1  ...    both  Mid range product  Regularly busy
# 12                  2  ...    both  Low range product  Regularly busy
# 13                  3  ...    both  Low range product  Regularly busy
# 14                  4  ...    both  Mid range product  Regularly busy
#
#     day_activity_level  busiest_period_of_day  max_order  loyalty_flag  \
# 0       Regularly busy         Average Orders         10  New customer
# 1       Regularly busy         Average Orders         10  New customer
# 2       Regularly busy         Average Orders         10  New customer
# 3       Regularly busy         Average Orders         10  New customer
# 4       Regularly busy         Average Orders         10  New customer
# 5   Least busiest days         Average Orders         10  New customer
# 6   Least busiest days         Average Orders         10  New customer
# 7   Least busiest days         Average Orders         10  New customer
# 8   Least busiest days         Average Orders         10  New customer
# 9   Least busiest days         Average Orders         10  New customer
# 10  Least busiest days         Average Orders         10  New customer
# 11  Least busiest days            Most Orders         10  New customer
# 12  Least busiest days            Most Orders         10  New customer
# 13  Least busiest days            Most Orders         10  New customer
# 14  Least busiest days            Most Orders         10  New customer
#
#    avg_product_price spending_flag medain_days_since_last_order
# 0           6.367797   Low Spender                         20.5
# 1           6.367797   Low Spender                         20.5
# 2           6.367797   Low Spender                         20.5
# 3           6.367797   Low Spender                         20.5
# 4           6.367797   Low Spender                         20.5
# 5           6.367797   Low Spender                         20.5
# 6           6.367797   Low Spender                         20.5
# 7           6.367797   Low Spender                         20.5
# 8           6.367797   Low Spender                         20.5
# 9           6.367797   Low Spender                         20.5
# 10          6.367797   Low Spender                         20.5
# 11          6.367797   Low Spender                         20.5
# 12          6.367797   Low Spender                         20.5
# 13          6.367797   Low Spender                         20.5
# 14          6.367797   Low Spender                         20.5
#
# [15 rows x 26 columns]

# %%
# Assigning order freq flag
df_ords_prods_merge.loc[df_ords_prods_merge['medain_days_since_last_order'] > 20, 'order_frequency_flag'] = 'Non-Frequent Customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['medain_days_since_last_order'] > 10) & (df_ords_prods_merge['medain_days_since_last_order'] <= 20), 'order_frequency_flag'] = 'Regular Customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['medain_days_since_last_order'] <= 10, 'order_frequency_flag'] = 'Frequent Customer'

# %%
df_ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent Customer        21559853
# Regular Customer          7208564
# Non-Frequent Customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %% [markdown]
# # 04. Exporting Data

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_grouped.pkl'))
